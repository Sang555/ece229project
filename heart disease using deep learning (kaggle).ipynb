# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F 
import seaborn as sns
import matplotlib.pyplot as plt
from torch.utils.data import Dataset

# %%
USE_GPU = True
num_class = 100
dtype = torch.float32 # we will be using float throughout this tutorial

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# Constant to control how frequently we print train loss
print_every = 100

print('using device:', device)
# Out:
# using device: cuda

# %%
df=pd.read_csv('heart.csv')

# %%
def convert_y(x):
    if x == "No":
        x = 0
    else:
        x = 1
    return x
df["HeartDisease"] = df["HeartDisease"].apply( lambda x: convert_y(x))
from sklearn.preprocessing import LabelEncoder
def label_transformation(x):
    le = LabelEncoder()
    le_encoded = le.fit_transform(x)
    return le_encoded
df_transformed = df.copy()
categorical_columns = ["Smoking","Stroke","DiffWalking","AlcoholDrinking","AgeCategory","Diabetic","GenHealth","Sex","Race", "PhysicalActivity","SkinCancer","KidneyDisease","Asthma"]
for x in categorical_columns:
    df_transformed[x] = label_transformation(df[x])
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_transformed[["BMI","PhysicalHealth","MentalHealth"]] = scaler.fit_transform(df_transformed[["BMI","PhysicalHealth","MentalHealth"]])
from sklearn.model_selection import train_test_split 
#X = df_transformed.drop("HeartDisease",axis=1)

#y = df_transformed["HeartDisease"]
# Train & Test split

#x_train=df_transformed
x_train, x_test= train_test_split(df_transformed,test_size=0.25,random_state=21)

# %%
class heartdataset(Dataset):
    def __init__(self, df):
        x=df.iloc[1:, 1:18].values
        y=df.iloc[1:, 0].values
        sc=StandardScaler()
        x_train=sc.fit_transform(x)
        self.X_train=torch.tensor(x_train, dtype=torch.float32)
        self.y_train=torch.tensor(y)
    def __len__(self):
        return len(self.y_train)
    def __getitem__(self, idx):
        return self.X_train[idx], self.y_train[idx]
x_train_loader=heartdataset(x_train)
x_test_loader=heartdataset(x_test)


x_train_loader = torch.utils.data.DataLoader(x_train_loader, batch_size=128, shuffle=True)
x_test_loader = torch.utils.data.DataLoader(x_test_loader, batch_size=128, shuffle=True)

# %%
df_transformed.head()
# Out:
#    HeartDisease       BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0 -1.844750        1                0       0       -0.046751
# 1             0 -1.256338        0                0       1       -0.424070
# 2             0 -0.274603        1                0       0        2.091388
# 3             0 -0.647473        0                0       0       -0.424070
# 4             0 -0.726138        0                0       0        3.097572
#
#    MentalHealth  DiffWalking  Sex  AgeCategory  Race  Diabetic  \
# 0      3.281069            0    0            7     5         2
# 1     -0.490039            0    0           12     5         0
# 2      3.281069            0    1            9     5         2
# 3     -0.490039            0    0           11     5         0
# 4     -0.490039            1    0            4     5         0
#
#    PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  SkinCancer
# 0                 1          4        5.0       1              0           1
# 1                 1          4        7.0       0              0           0
# 2                 1          1        8.0       1              0           0
# 3                 0          2        6.0       0              0           1
# 4                 1          4        8.0       0              0           0

# %%
class heart(nn.Module):
    def __init__(self):
        super().__init__()
      
        self.fc1 = nn.Linear(17, 1000)
        self.fc2 = nn.Linear(1000, 500)
        self.fc3 = nn.Linear(500, 2)
        self.Sigmoid = nn.Sigmoid()
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        scores = None

        x=self.relu(self.fc1(x))
        x=self.relu(self.fc2(x))

        scores=self.fc3(x)

        return scores
#319795

# %%
def train_heart(model, optimizer, epochs=10):
    model = model.to(device=device)  # move the model parameters to CPU/GPU
    for e in range(epochs):
        for t, (x,y) in enumerate(x_train_loader):

            model.train()  # put model to training mode
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)

            scores = model(x)
            loss = F.cross_entropy(scores, y)

            # Zero out all of the gradients for the variables which the optimizer
            # will update.
            optimizer.zero_grad()

            # This is the backwards pass: compute the gradient of the loss with
            # respect to each  parameter of the model.
            loss.backward()

            # Actually update the parameters of the model using the gradients
            # computed by the backwards pass.
            optimizer.step()

            if t % print_every == 0:
                print('Epoch %d, Iteration %d, loss = %.4f' % (e, t, loss.item()))
                check_accuracy_heart(x_test_loader, model)
                print()

# %%
def check_accuracy_heart(x_test_loader, model):

    num_correct = 0
    num_samples = 0
    model.eval()  # set model to evaluation mode
    with torch.no_grad():
        for x,y in x_test_loader: 
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            scores = model(x)
            _, preds = scores.max(1)
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))

# %%
learning_rate=1e-5
model = heart()
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

train_heart(model, optimizer)
# Out:
# Epoch 0, Iteration 0, loss = 0.7043
# Got 32184 / 79948 correct (40.26)
#
# Epoch 0, Iteration 100, loss = 0.7039
# Got 35551 / 79948 correct (44.47)
#
# Epoch 0, Iteration 200, loss = 0.6999
# Got 38741 / 79948 correct (48.46)
#
# Epoch 0, Iteration 300, loss = 0.6824
# Got 42058 / 79948 correct (52.61)
#
# Epoch 0, Iteration 400, loss = 0.6841
# Got 45098 / 79948 correct (56.41)
#
# Epoch 0, Iteration 500, loss = 0.6831
# Got 48057 / 79948 correct (60.11)
#
# Epoch 0, Iteration 600, loss = 0.6796
# Got 50937 / 79948 correct (63.71)
#
# Epoch 0, Iteration 700, loss = 0.6693
# Got 53603 / 79948 correct (67.05)
#
# Epoch 0, Iteration 800, loss = 0.6614
# Got 56345 / 79948 correct (70.48)
#
# Epoch 0, Iteration 900, loss = 0.6684
# Got 58991 / 79948 correct (73.79)
#
# Epoch 0, Iteration 1000, loss = 0.6642
# Got 61834 / 79948 correct (77.34)
#
# Epoch 0, Iteration 1100, loss = 0.6497
# Got 64533 / 79948 correct (80.72)
#
# Epoch 0, Iteration 1200, loss = 0.6420
# Got 66919 / 79948 correct (83.70)
#
# Epoch 0, Iteration 1300, loss = 0.6459
# Got 68853 / 79948 correct (86.12)
#
# Epoch 0, Iteration 1400, loss = 0.6454
# Got 70086 / 79948 correct (87.66)
#
# Epoch 0, Iteration 1500, loss = 0.6384
# Got 70865 / 79948 correct (88.64)
#
# Epoch 0, Iteration 1600, loss = 0.6330
# Got 71375 / 79948 correct (89.28)
#
# Epoch 0, Iteration 1700, loss = 0.6369
# Got 71782 / 79948 correct (89.79)
#
# Epoch 0, Iteration 1800, loss = 0.6203
# Got 72206 / 79948 correct (90.32)
#
# Epoch 1, Iteration 0, loss = 0.6298
# Got 72470 / 79948 correct (90.65)
#
# Epoch 1, Iteration 100, loss = 0.6127
# Got 72686 / 79948 correct (90.92)
#
# Epoch 1, Iteration 200, loss = 0.6103
# Got 72807 / 79948 correct (91.07)
#
# Epoch 1, Iteration 300, loss = 0.6046
# Got 72922 / 79948 correct (91.21)
#
# Epoch 1, Iteration 400, loss = 0.6058
# Got 72983 / 79948 correct (91.29)
#
# Epoch 1, Iteration 500, loss = 0.6059
# Got 73036 / 79948 correct (91.35)
#
# Epoch 1, Iteration 600, loss = 0.5954
# Got 73076 / 79948 correct (91.40)
#
# Epoch 1, Iteration 700, loss = 0.5987
# Got 73096 / 79948 correct (91.43)
#
# Epoch 1, Iteration 800, loss = 0.5928
# Got 73107 / 79948 correct (91.44)
#
# Epoch 1, Iteration 900, loss = 0.5752
# Got 73110 / 79948 correct (91.45)
#
# Epoch 1, Iteration 1000, loss = 0.6057
# Got 73111 / 79948 correct (91.45)
#
# Epoch 1, Iteration 1100, loss = 0.5716
# Got 73111 / 79948 correct (91.45)
#
# Epoch 1, Iteration 1200, loss = 0.5776
# Got 73111 / 79948 correct (91.45)
#
# Epoch 1, Iteration 1300, loss = 0.5915
# Got 73112 / 79948 correct (91.45)
#
# Epoch 1, Iteration 1400, loss = 0.5692
# Got 73113 / 79948 correct (91.45)
#
# Epoch 1, Iteration 1500, loss = 0.5715
# Got 73113 / 79948 correct (91.45)
#
# Epoch 1, Iteration 1600, loss = 0.5626
# Got 73113 / 79948 correct (91.45)
#
# Epoch 1, Iteration 1700, loss = 0.5705
# Got 73113 / 79948 correct (91.45)
#
# Epoch 1, Iteration 1800, loss = 0.5468
# Got 73113 / 79948 correct (91.45)
#
# Epoch 2, Iteration 0, loss = 0.5638
# Got 73113 / 79948 correct (91.45)
#
# Epoch 2, Iteration 100, loss = 0.5530
# Got 73113 / 79948 correct (91.45)
#
# Epoch 2, Iteration 200, loss = 0.5526
# Got 73113 / 79948 correct (91.45)
#
# Epoch 2, Iteration 300, loss = 0.5539
# Got 73113 / 79948 correct (91.45)
#
# Epoch 2, Iteration 400, loss = 0.5539
# Got 73113 / 79948 correct (91.45)
#
# Epoch 2, Iteration 500, loss = 0.5550
# Got 73113 / 79948 correct (91.45)
#
# Epoch 2, Iteration 600, loss = 0.5503
# Got 73113 / 79948 correct (91.45)
#
# Epoch 2, Iteration 700, loss = 0.5103
# Got 73113 / 79948 correct (91.45)
#
# Epoch 2, Iteration 800, loss = 0.5340
# Got 73113 / 79948 correct (91.45)
#
# Epoch 2, Iteration 900, loss = 0.5272
# Got 73113 / 79948 correct (91.45)
#
# Epoch 2, Iteration 1000, loss = 0.5257
# Got 73113 / 79948 correct (91.45)
#
# Epoch 2, Iteration 1100, loss = 0.5443
# Got 73113 / 79948 correct (91.45)
#
# Epoch 2, Iteration 1200, loss = 0.5155
# Got 73113 / 79948 correct (91.45)
#
# Epoch 2, Iteration 1300, loss = 0.5388
# Got 73113 / 79948 correct (91.45)
#
# Epoch 2, Iteration 1400, loss = 0.5149
# Got 73113 / 79948 correct (91.45)
#
# Epoch 2, Iteration 1500, loss = 0.5404
# Got 73113 / 79948 correct (91.45)
#
# Epoch 2, Iteration 1600, loss = 0.5262
# Got 73113 / 79948 correct (91.45)
#
# Epoch 2, Iteration 1700, loss = 0.5236
# Got 73113 / 79948 correct (91.45)
#
# Epoch 2, Iteration 1800, loss = 0.5338
# Got 73113 / 79948 correct (91.45)
#
# Epoch 3, Iteration 0, loss = 0.5337
# Got 73113 / 79948 correct (91.45)
#
# Epoch 3, Iteration 100, loss = 0.5015
# Got 73113 / 79948 correct (91.45)
#
# Epoch 3, Iteration 200, loss = 0.4993
# Got 73113 / 79948 correct (91.45)
#
# Epoch 3, Iteration 300, loss = 0.4929
# Got 73113 / 79948 correct (91.45)
#
# Epoch 3, Iteration 400, loss = 0.5038
# Got 73113 / 79948 correct (91.45)
#
# Epoch 3, Iteration 500, loss = 0.4885
# Got 73113 / 79948 correct (91.45)
#
# Epoch 3, Iteration 600, loss = 0.4888
# Got 73113 / 79948 correct (91.45)
#
# Epoch 3, Iteration 700, loss = 0.5220
# Got 73113 / 79948 correct (91.45)
#
# Epoch 3, Iteration 800, loss = 0.4866
# Got 73113 / 79948 correct (91.45)
#
# Epoch 3, Iteration 900, loss = 0.4711
# Got 73113 / 79948 correct (91.45)
#
# Epoch 3, Iteration 1000, loss = 0.4771
# Got 73113 / 79948 correct (91.45)
#
# Epoch 3, Iteration 1100, loss = 0.5109
# Got 73113 / 79948 correct (91.45)
#
# Epoch 3, Iteration 1200, loss = 0.5060
# Got 73113 / 79948 correct (91.45)
#
# Epoch 3, Iteration 1300, loss = 0.5191
# Got 73113 / 79948 correct (91.45)
#
# Epoch 3, Iteration 1400, loss = 0.4709
# Got 73113 / 79948 correct (91.45)
#
# Epoch 3, Iteration 1500, loss = 0.4626
# Got 73113 / 79948 correct (91.45)
#
# Epoch 3, Iteration 1600, loss = 0.4843
# Got 73113 / 79948 correct (91.45)
#
# Epoch 3, Iteration 1700, loss = 0.4898
# Got 73113 / 79948 correct (91.45)
#
# Epoch 3, Iteration 1800, loss = 0.4681
# Got 73113 / 79948 correct (91.45)
#
# Epoch 4, Iteration 0, loss = 0.4743
# Got 73113 / 79948 correct (91.45)
#
# Epoch 4, Iteration 100, loss = 0.4440
# Got 73113 / 79948 correct (91.45)
#
# Epoch 4, Iteration 200, loss = 0.4991
# Got 73113 / 79948 correct (91.45)
#
# Epoch 4, Iteration 300, loss = 0.4671
# Got 73113 / 79948 correct (91.45)
#
# Epoch 4, Iteration 400, loss = 0.4779
# Got 73113 / 79948 correct (91.45)
#
# Epoch 4, Iteration 500, loss = 0.4450
# Got 73113 / 79948 correct (91.45)
#
# Epoch 4, Iteration 600, loss = 0.4769
# Got 73113 / 79948 correct (91.45)
#
# Epoch 4, Iteration 700, loss = 0.4471
# Got 73113 / 79948 correct (91.45)
#
# Epoch 4, Iteration 800, loss = 0.4534
# Got 73113 / 79948 correct (91.45)
#
# Epoch 4, Iteration 900, loss = 0.4814
# Got 73113 / 79948 correct (91.45)
#
# Epoch 4, Iteration 1000, loss = 0.4629
# Got 73113 / 79948 correct (91.45)
#
# Epoch 4, Iteration 1100, loss = 0.4237
# Got 73113 / 79948 correct (91.45)
#
# Epoch 4, Iteration 1200, loss = 0.4465
# Got 73113 / 79948 correct (91.45)
#
# Epoch 4, Iteration 1300, loss = 0.4596
# Got 73113 / 79948 correct (91.45)
#
# Epoch 4, Iteration 1400, loss = 0.4599
# Got 73113 / 79948 correct (91.45)
#
# Epoch 4, Iteration 1500, loss = 0.4924
# Got 73113 / 79948 correct (91.45)
#
# Epoch 4, Iteration 1600, loss = 0.4721
# Got 73113 / 79948 correct (91.45)
#
# Epoch 4, Iteration 1700, loss = 0.4403
# Got 73113 / 79948 correct (91.45)
#
# Epoch 4, Iteration 1800, loss = 0.4636
# Got 73113 / 79948 correct (91.45)
#
# Epoch 5, Iteration 0, loss = 0.4263
# Got 73113 / 79948 correct (91.45)
#
# Epoch 5, Iteration 100, loss = 0.4837
# Got 73113 / 79948 correct (91.45)
#
# Epoch 5, Iteration 200, loss = 0.4341
# Got 73113 / 79948 correct (91.45)
#
# Epoch 5, Iteration 300, loss = 0.4395
# Got 73113 / 79948 correct (91.45)
#
# Epoch 5, Iteration 400, loss = 0.4567
# Got 73113 / 79948 correct (91.45)
#
# Epoch 5, Iteration 500, loss = 0.4532
# Got 73113 / 79948 correct (91.45)
#
# Epoch 5, Iteration 600, loss = 0.4129
# Got 73113 / 79948 correct (91.45)
#
# Epoch 5, Iteration 700, loss = 0.4099
# Got 73113 / 79948 correct (91.45)
#
# Epoch 5, Iteration 800, loss = 0.3844
# Got 73113 / 79948 correct (91.45)
#
# Epoch 5, Iteration 900, loss = 0.4447
# Got 73113 / 79948 correct (91.45)
#
# Epoch 5, Iteration 1000, loss = 0.4602
# Got 73113 / 79948 correct (91.45)
#
# Epoch 5, Iteration 1100, loss = 0.4704
# Got 73113 / 79948 correct (91.45)
#
# Epoch 5, Iteration 1200, loss = 0.4414
# Got 73113 / 79948 correct (91.45)
#
# Epoch 5, Iteration 1300, loss = 0.4299
# Got 73113 / 79948 correct (91.45)
#
# Epoch 5, Iteration 1400, loss = 0.4054
# Got 73113 / 79948 correct (91.45)
#
# Epoch 5, Iteration 1500, loss = 0.4225
# Got 73113 / 79948 correct (91.45)
#
# Epoch 5, Iteration 1600, loss = 0.3889
# Got 73113 / 79948 correct (91.45)
#
# Epoch 5, Iteration 1700, loss = 0.4385
# Got 73113 / 79948 correct (91.45)
#
# Epoch 5, Iteration 1800, loss = 0.3884
# Got 73113 / 79948 correct (91.45)
#
# Epoch 6, Iteration 0, loss = 0.4097
# Got 73113 / 79948 correct (91.45)
#
# Epoch 6, Iteration 100, loss = 0.4124
# Got 73113 / 79948 correct (91.45)
#
# Epoch 6, Iteration 200, loss = 0.3972
# Got 73113 / 79948 correct (91.45)
#
# Epoch 6, Iteration 300, loss = 0.4130
# Got 73113 / 79948 correct (91.45)
#
# Epoch 6, Iteration 400, loss = 0.4105
# Got 73113 / 79948 correct (91.45)
#
# Epoch 6, Iteration 500, loss = 0.4015
# Got 73113 / 79948 correct (91.45)
#
# Epoch 6, Iteration 600, loss = 0.4305
# Got 73113 / 79948 correct (91.45)
#
# Epoch 6, Iteration 700, loss = 0.4222
# Got 73113 / 79948 correct (91.45)
#
# Epoch 6, Iteration 800, loss = 0.3668
# Got 73113 / 79948 correct (91.45)
#
# Epoch 6, Iteration 900, loss = 0.3966
# Got 73113 / 79948 correct (91.45)
#
# Epoch 6, Iteration 1000, loss = 0.4634
# Got 73113 / 79948 correct (91.45)
#
# Epoch 6, Iteration 1100, loss = 0.4302
# Got 73113 / 79948 correct (91.45)
#
# Epoch 6, Iteration 1200, loss = 0.4239
# Got 73113 / 79948 correct (91.45)
#
# Epoch 6, Iteration 1300, loss = 0.4001
# Got 73113 / 79948 correct (91.45)
#
# Epoch 6, Iteration 1400, loss = 0.3646
# Got 73113 / 79948 correct (91.45)
#
# Epoch 6, Iteration 1500, loss = 0.3850
# Got 73113 / 79948 correct (91.45)
#
# Epoch 6, Iteration 1600, loss = 0.4580
# Got 73113 / 79948 correct (91.45)
#
# Epoch 6, Iteration 1700, loss = 0.3645
# Got 73113 / 79948 correct (91.45)
#
# Epoch 6, Iteration 1800, loss = 0.3585
# Got 73113 / 79948 correct (91.45)
#
# Epoch 7, Iteration 0, loss = 0.4604
# Got 73113 / 79948 correct (91.45)
#
# Epoch 7, Iteration 100, loss = 0.3916
# Got 73113 / 79948 correct (91.45)
#
# Epoch 7, Iteration 200, loss = 0.4098
# Got 73113 / 79948 correct (91.45)
#
# Epoch 7, Iteration 300, loss = 0.3810
# Got 73113 / 79948 correct (91.45)
#
# Epoch 7, Iteration 400, loss = 0.4190
# Got 73113 / 79948 correct (91.45)
#
# Epoch 7, Iteration 500, loss = 0.3711
# Got 73113 / 79948 correct (91.45)
#
# Epoch 7, Iteration 600, loss = 0.4261
# Got 73113 / 79948 correct (91.45)
#
# Epoch 7, Iteration 700, loss = 0.4053
# Got 73113 / 79948 correct (91.45)
#
# Epoch 7, Iteration 800, loss = 0.3684
# Got 73113 / 79948 correct (91.45)
#
# Epoch 7, Iteration 900, loss = 0.4134
# Got 73113 / 79948 correct (91.45)
#
# Epoch 7, Iteration 1000, loss = 0.4685
# Got 73113 / 79948 correct (91.45)
#
# Epoch 7, Iteration 1100, loss = 0.3445
# Got 73113 / 79948 correct (91.45)
#
# Epoch 7, Iteration 1200, loss = 0.4170
# Got 73113 / 79948 correct (91.45)
#
# Epoch 7, Iteration 1300, loss = 0.4187
# Got 73113 / 79948 correct (91.45)
#
# Epoch 7, Iteration 1400, loss = 0.3871
# Got 73113 / 79948 correct (91.45)
#
# Epoch 7, Iteration 1500, loss = 0.3430
# Got 73113 / 79948 correct (91.45)
#
# Epoch 7, Iteration 1600, loss = 0.4227
# Got 73113 / 79948 correct (91.45)
#
# Epoch 7, Iteration 1700, loss = 0.3861
# Got 73113 / 79948 correct (91.45)
#
# Epoch 7, Iteration 1800, loss = 0.3768
# Got 73113 / 79948 correct (91.45)
#
# Epoch 8, Iteration 0, loss = 0.4097
# Got 73113 / 79948 correct (91.45)
#
# Epoch 8, Iteration 100, loss = 0.4353
# Got 73113 / 79948 correct (91.45)
#
# Epoch 8, Iteration 200, loss = 0.3274
# Got 73113 / 79948 correct (91.45)
#
# Epoch 8, Iteration 300, loss = 0.3609
# Got 73113 / 79948 correct (91.45)
#
# Epoch 8, Iteration 400, loss = 0.3966
# Got 73113 / 79948 correct (91.45)
#
# Epoch 8, Iteration 500, loss = 0.3958
# Got 73113 / 79948 correct (91.45)
#
# Epoch 8, Iteration 600, loss = 0.4357
# Got 73113 / 79948 correct (91.45)
#
# Epoch 8, Iteration 700, loss = 0.4164
# Got 73113 / 79948 correct (91.45)
#
# Epoch 8, Iteration 800, loss = 0.4045
# Got 73113 / 79948 correct (91.45)
#
# Epoch 8, Iteration 900, loss = 0.4439
# Got 73113 / 79948 correct (91.45)
#
# Epoch 8, Iteration 1000, loss = 0.3661
# Got 73113 / 79948 correct (91.45)
#
# Epoch 8, Iteration 1100, loss = 0.4084
# Got 73113 / 79948 correct (91.45)
#
# Epoch 8, Iteration 1200, loss = 0.3999
# Got 73113 / 79948 correct (91.45)
#
# Epoch 8, Iteration 1300, loss = 0.3247
# Got 73113 / 79948 correct (91.45)
#
# Epoch 8, Iteration 1400, loss = 0.3705
# Got 73113 / 79948 correct (91.45)
#
# Epoch 8, Iteration 1500, loss = 0.3448
# Got 73113 / 79948 correct (91.45)
#
# Epoch 8, Iteration 1600, loss = 0.3633
# Got 73113 / 79948 correct (91.45)
#
# Epoch 8, Iteration 1700, loss = 0.3898
# Got 73113 / 79948 correct (91.45)
#
# Epoch 8, Iteration 1800, loss = 0.3726
# Got 73113 / 79948 correct (91.45)
#
# Epoch 9, Iteration 0, loss = 0.3703
# Got 73113 / 79948 correct (91.45)
#
# Epoch 9, Iteration 100, loss = 0.3768
# Got 73113 / 79948 correct (91.45)
#
# Epoch 9, Iteration 200, loss = 0.3423
# Got 73113 / 79948 correct (91.45)
#
# Epoch 9, Iteration 300, loss = 0.3464
# Got 73113 / 79948 correct (91.45)
#
# Epoch 9, Iteration 400, loss = 0.3830
# Got 73113 / 79948 correct (91.45)
#
# Epoch 9, Iteration 500, loss = 0.4058
# Got 73113 / 79948 correct (91.45)
#
# Epoch 9, Iteration 600, loss = 0.3082
# Got 73113 / 79948 correct (91.45)
#
# Epoch 9, Iteration 700, loss = 0.3907
# Got 73113 / 79948 correct (91.45)
#
# Epoch 9, Iteration 800, loss = 0.4328
# Got 73113 / 79948 correct (91.45)
#
# Epoch 9, Iteration 900, loss = 0.3714
# Got 73113 / 79948 correct (91.45)
#
# Epoch 9, Iteration 1000, loss = 0.3991
# Got 73113 / 79948 correct (91.45)
#
# Epoch 9, Iteration 1100, loss = 0.3843
# Got 73113 / 79948 correct (91.45)
#
# Epoch 9, Iteration 1200, loss = 0.3453
# Got 73113 / 79948 correct (91.45)
#
# Epoch 9, Iteration 1300, loss = 0.3528
# Got 73113 / 79948 correct (91.45)
#
# Epoch 9, Iteration 1400, loss = 0.3685
# Got 73113 / 79948 correct (91.45)
#
# Epoch 9, Iteration 1500, loss = 0.4119
# Got 73113 / 79948 correct (91.45)
#
# Epoch 9, Iteration 1600, loss = 0.3379
# Got 73113 / 79948 correct (91.45)
#
# Epoch 9, Iteration 1700, loss = 0.3926
# Got 73113 / 79948 correct (91.45)
#
# Epoch 9, Iteration 1800, loss = 0.3380
# Got 73113 / 79948 correct (91.45)
